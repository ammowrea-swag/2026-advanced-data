# %%
## In 2025, the acme company had 5.3 million dollars in widget sales. It had expenses of 2.6 million and paid 875k in taxes. What is the net profit? Print an ouput that reads "In 2025, the ACME company had TK in net profits, TK in expenses and TK in taxes"

# %%
sales=5300000
expenses=2600000
taxes=875000

# %%
print(sales)
# Out:
# 5300000

# %%
net=sales-expenses-taxes
print(net)
# Out:
# 1825000

# %%
net_m=(net/100000)

# %%
print(f"In 2025, the ACME company had $ {sales:,} in net sales. It had $ {expenses:,} and paid $ {taxes:,} in taxes. The net profit is $ {net:,}")
# Out:
# In 2025, the ACME company had $ 5,300,000 in net sales. It had $ 2,600,000 and paid $ 875,000 in taxes. The net profit is $ 1,825,000

# %%
abs(-14)
# Out:
# 14

# %%
len(28839299506983718)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 len(28839299506983718)
#
# TypeError: object of type 'int' has no len()

# %%
type(45)
# Out:
# int

# %%
type(3.28)
# Out:
# float

# %%
animals = ["rat", "cat", "horse", "bee", "manatee", "rabbit", "shrimp"]

# %%
print(animals)
# Out:
# ['rat', 'cat', 'horse', 'bee', 'manatee', 'rabbit', 'shrimp']

# %%
type(animals)
# Out:
# list

# %%
## build and call the car_1 dictionary 

car_1={"brand":"Audi", "body":"SUV", "model":"Q4", "trim":"leather", "cost": 60_000, "on_sale" : False, "vin":"2973", "type": "EV"}

# %%
print(car_1)
# Out:
# {'brand': 'Audi', 'body': 'SUV', 'model': 'Q4', 'trim': 'leather', 'cost': 60000, 'on_sale': False, 'vin': '2973', 'type': 'EV'}

# %%
import pandas as pd

# %%
pd.read_csv("insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
